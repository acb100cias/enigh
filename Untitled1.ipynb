# %%
import bamboolib as bam
from pandas import *
from numpy import *
data=read_csv('rurales_cuMun_22_3_2022.csv')

# %%
data
# Out:
#          folioviv  foliohog  pertenece a etnia  no pertenece a etnia  \
# 0       160006213         1                  0                     6
# 1       160006214         1                  0                     1
# 2       160006215         1                  0                     1
# 3       160006216         1                  0                     2
# 4       160006217         1                  0                     4
# ...           ...       ...                ...                   ...
# 28589  3260798902         1                  0                     2
# 28590  3260798903         1                  0                     2
# 28591  3260798904         1                  0                     7
# 28592  3260798905         1                  0                     1
# 28593  3260798906         1                  0                     2
#
#        ubica_geo  tam_loc  est_socio  est_dis   upm  factor  ...   LPEI  \
# ...

# %%
read_csv('autoconsumo_5_4_2021.csv').drop('Unnamed: 0', axis=1).to_csv('rurales_auto_consumo.csv',index=False)
