# %%
from pandas import *

# %% [markdown]
# # Estadísticos sobre ingresos en hogares rurales
#
# ## Tabla 1. Población rural por edad y región

# %%
DATA=read_csv('rurales_cuMun_26_8_2021.csv').drop('Unnamed: 0',axis=1)

# %%
DATA.
# Out:
#          folioviv  foliohog  pertenece a etnia  no pertenece a etnia  \
# 0       160006213         1                  0                     6
# 1       160006214         1                  0                     1
# 2       160006215         1                  0                     1
# 3       160006216         1                  0                     2
# 4       160006217         1                  0                     4
# ...           ...       ...                ...                   ...
# 28589  3260798902         1                  0                     2
# 28590  3260798903         1                  0                     2
# 28591  3260798904         1                  0                     7
# 28592  3260798905         1                  0                     1
# 28593  3260798906         1                  0                     2
#
#        ubica_geo  tam_loc  est_socio  est_dis   upm  factor  ...  \
# 0           1001        4          2       10   248      86  ...
# ...
