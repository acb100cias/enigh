# %%
from pandas import *

# %%
from numpy import *
from INEGIpy import *

# %%
muns = ['021','039','046','048','049','019','026','006'] #claves de municipios correspondientes a la Zona Metropolitana de Monterrey
zmmty_manzanas = marco.Manzanas(entidades = '19', municipios = muns)
zmmty_manzanas.plot()
# Out:
# <AxesSubplot:>

# %%
marco = MarcoGeoestadistico()

# %%
marco.Entidades().plot()
# Out:
# <AxesSubplot:>

# %%
token = 'ad8857d8-1098-9c33-313f-7765dd1d4acf'
inegi = Indicadores(token)

# %%
DENUE(token).Cuantificar(clave_area = '0',clave_actividad = '0',estrato = '0')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-30-32ba82187888> in <module>
# ----> 1 DENUE(token).Cuantificar(clave_area = '0',clave_actividad = '0',estrato = '0')
#
# /usr/local/lib/python3.9/dist-packages/INEGIpy/_denue.py in Cuantificar(self, clave_area, clave_actividad, estrato)
#     260         if isinstance(clave_area, list): clave_area = ','.join(clave_area)
#     261         liga = self.__liga_base + 'Cuantificar/{}/{}/{}/{}'.format(clave_actividad, clave_area, estrato, self.__token)
# --> 262         return self.__obtener_consulta(liga, False)
#     263
#
# /usr/local/lib/python3.9/dist-packages/INEGIpy/_denue.py in __obtener_consulta(self, liga, as_geodf)
#      29     def __obtener_consulta(self, liga, as_geodf):
#      30         req = requests.get(liga)
# ---> 31         assert req.status_code == 200, 'No se encontró información con las parámetros especificados. \n Liga: {}'.format(liga)
#      32         data = json.loads(req.text)
#      33         df = pd.DataFrame(data)
#
# AssertionError: No se encontró información con las parámetros especificados.
#  Liga: https://www.inegi.org.mx/app/api/denue/v1/consulta/Cuantificar/0/0/0/ad8857d8-1098-9c33-313f-7765dd1d4acf
