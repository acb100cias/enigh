# %%
from pandas import *
from numpy import *
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/compat/_optional.py:149: UserWarning: Pandas requires version '1.3.1' or newer of 'bottleneck' (version '1.2.1' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
rurales=read_csv('rurales_22_02_23.csv')

# %%
TIng=rurales.filter(['IngresoTrab','agrope','noagrop','rentas','transfer','otros_ing','tipo_hogar','CUmun2','Region']).pivot_table(index=['tipo_hogar','CUmun2'],aggfunc=lambda x:0.3*x.mean(),margins=True,margins_name='Total Ingresos Mensual').round(2)
# Out:
# <ipython-input-117-7f9ba89dd88b>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.agg is deprecated. In a future version, a TypeError will be raised. Before calling .agg, select only columns which should be valid for the function.
#   TIng=rurales.filter(['IngresoTrab','agrope','noagrop','rentas','transfer','otros_ing','tipo_hogar','CUmun2','Region']).pivot_table(index=['tipo_hogar','CUmun2'],aggfunc=lambda x:0.3*x.mean(),margins=True,margins_name='Total Ingresos Mensual').round(2)

# %%
TIng=TIng.T.rename(columns={0:'Localidad mixta',1:'Cercana a ciudad',2:'Cercana a localidad mixta',3:'Cercano a carretera',4:'Aislada'}).T

# %%
TIng['Total Ingresos Mensual']=TIng.T.sum()

# %%
TIng=TIng.rename(columns={'IngresoTrab':'Ingresos por Trabajo','agrope':'Agropecuarios','noagrop':'No agropecuarios','otros_ing':'Otros Ingresos','rentas':'Rentas','transfer':'Transferencias'})

# %%
TIng2=rurales.filter(['tipo_hogar','CUmun2','Region']).pivot_table(index=['tipo_hogar','CUmun2'],aggfunc=mean,margins=True,margins_name='Total Ingresos Mensual').round(2)
# Out:
# <ipython-input-121-e9974257cc3c>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   TIng2=rurales.filter(['tipo_hogar','CUmun2','Region']).pivot_table(index=['tipo_hogar','CUmun2'],aggfunc=mean,margins=True,margins_name='Total Ingresos Mensual').round(2)

# %%
TIng2['Total Ingresos Mensual %']=TIng['Total Ingresos Mensual'].values

# %%
for i in TIng.keys():
    TIng2[i+' %']=100*(TIng[i].values/TIng['Total Ingresos Mensual'].values)

# %%
TIng2=TIng2.round(2)

# %%
TIng2=TIng2.T.rename(columns={0:'Localidad mixta',1:'Cercana a ciudad',2:'Cercana a localidad mixta',3:'Cercano a carretera',4:'Aislada'}).T

# %%
TIng2=TIng2.rename(columns={'IngresoTrab %':'Ingresos por Trabajo %','agrope %':'Agropecuarios %','noagrop %':'No agropecuarios %','otros_ing %':'Otros Ingresos %','rentas %':'Rentas %','transfer %':'Transferencias %'})

# %%
TIng2
# Out:
#                                                   Total Ingresos Mensual %  \
# tipo_hogar             CUmun2
# Sin ingresos propios   Localidad mixta                               100.0
#                        Cercana a ciudad                              100.0
#                        Cercana a localidad mixta                     100.0
#                        Cercano a carretera                           100.0
#                        Aislada                                       100.0
# UCE                    Localidad mixta                               100.0
#                        Cercana a ciudad                              100.0
#                        Cercana a localidad mixta                     100.0
#                        Cercano a carretera                           100.0
#                        Aislada                                       100.0
# UCEP                   Cercana a ciudad                              100.0
# ...

# %%
TIng.to_excel('Ingresos mensuales promedio por tipo de hogar y ubicacion.xlsx')
TIng2.to_excel('Ingresos mensuales promedio por tipo de hogar y ubicacion porcentaje.xlsx')

# %%
TIng3=rurales.filter(['jubilacion', 'becas','donativos', 'remesas', 'bene_gob', 'transf_hog', 'trans_inst','tipo_hogar','CUmun2','Region']).pivot_table(index=['tipo_hogar','CUmun2'],aggfunc=lambda x:0.3*x.mean(),margins=True,margins_name='Total Ingresos Transfer').round(2)
# Out:
# <ipython-input-151-92889878db10>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.agg is deprecated. In a future version, a TypeError will be raised. Before calling .agg, select only columns which should be valid for the function.
#   TIng3=rurales.filter(['jubilacion', 'becas','donativos', 'remesas', 'bene_gob', 'transf_hog', 'trans_inst','tipo_hogar','CUmun2','Region']).pivot_table(index=['tipo_hogar','CUmun2'],aggfunc=lambda x:0.3*x.mean(),margins=True,margins_name='Total Ingresos Transfer').round(2)

# %%
TIng3['Total Ingresos Transfer']=TIng3.T.sum()

# %%
TIng3=TIng3.T.rename(columns={0:'Localidad mixta',1:'Cercana a ciudad',2:'Cercana a localidad mixta',3:'Cercano a carretera',4:'Aislada'}).T

# %%
TIng3
# Out:
#                                                    becas  bene_gob  donativos  \
# tipo_hogar              CUmun2
# Sin ingresos propios    Localidad mixta             0.00   1035.33     733.41
#                         Cercana a ciudad           43.69    780.90     842.10
#                         Cercana a localidad mixta  26.54    846.44     841.71
#                         Cercano a carretera         9.79    958.55     761.30
#                         Aislada                     1.73    945.24     888.78
# UCE                     Localidad mixta             0.00    388.68     222.53
#                         Cercana a ciudad            5.21    605.03     332.19
#                         Cercana a localidad mixta   0.00    600.80     354.09
#                         Cercano a carretera        13.50    770.26     331.07
#                         Aislada                    23.45    823.58     280.62
# UCEP                    Cercana a ciudad           78.33    778.68     395.01
# ...

# %%
TIng4=rurales.filter(['tipo_hogar','CUmun2','Region']).pivot_table(index=['tipo_hogar','CUmun2'],aggfunc=mean,margins=True,margins_name='Total Ingresos Mensual').round(2)
# Out:
# <ipython-input-157-a1ae2acf99e1>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   TIng4=rurales.filter(['tipo_hogar','CUmun2','Region']).pivot_table(index=['tipo_hogar','CUmun2'],aggfunc=mean,margins=True,margins_name='Total Ingresos Mensual').round(2)

# %%
TIng4['Total Ingresos Transfer %']=TIng3['Total Ingresos Transfer'].values

# %%
for i in TIng3.keys():
    TIng4[i+' %']=100*(TIng3[i].values/TIng3['Total Ingresos Transfer'].values)

# %%
TIng4=TIng4.round(2)

# %%
TIng4=TIng4.T.rename(columns={0:'Localidad mixta',1:'Cercana a ciudad',2:'Cercana a localidad mixta',3:'Cercano a carretera',4:'Aislada'}).T

# %%
TIng4
# Out:
#                                                   Total Ingresos Transfer %  \
# tipo_hogar             CUmun2
# Sin ingresos propios   Localidad mixta                                100.0
#                        Cercana a ciudad                               100.0
#                        Cercana a localidad mixta                      100.0
#                        Cercano a carretera                            100.0
#                        Aislada                                        100.0
# UCE                    Localidad mixta                                100.0
#                        Cercana a ciudad                               100.0
#                        Cercana a localidad mixta                      100.0
#                        Cercano a carretera                            100.0
#                        Aislada                                        100.0
# UCEP                   Cercana a ciudad                               100.0
# ...

# %%
TIng3.to_excel('Ingresos mensuales promedio por transferencias por tipo de hogar y ubicacion.xlsx')
TIng4.to_excel('Ingresos mensuales promedio por transferencias por tipo de hogar y ubicacion porcentaje.xlsx')

# %%
TInd=rurales.filter(['Region','CUmun2','tipo_hogar','factor']).loc[rurales['pertenece a etnia']!=0].pivot_table(index=['Region','CUmun2'],columns='tipo_hogar',aggfunc=sum,margins=True,margins_name='Total').fillna(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-04d5386b922f> in <module>
# ----> 1 TInd=rurales.filter(['Region','CUmun2','tipo_hogar','factor']).loc[rurales['pertenece a etnia']!=0].pivot_table(index=['Region','CUmun2'],columns='tipo_hogar',aggfunc=sum,margins=True,margins_name='Total').fillna(0)
#
# NameError: name 'rurales' is not defined

# %%
TInd=TInd.rename(columns={'pertenece a etnia':'Hogares Indigenas'},index={0:'Localidad mixta',1:'Cercana a ciudad',2:'Cercana a localidad mixta',3:'Cercano a carretera',4:'Aislada'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c84b816a5422> in <module>
# ----> 1 TInd=TInd.rename(columns={'pertenece a etnia':'Hogares Indigenas'},index={0:'Localidad mixta',1:'Cercana a ciudad',2:'Cercana a localidad mixta',3:'Cercano a carretera',4:'Aislada'})
#
# NameError: name 'TInd' is not defined

# %%
TInd.rename(columns={'factor':'Hogares'}).astype('int').to_excel('hogares indigenas por region y CU.xlsx')

# %%
TInd=TInd.astype('int')

# %%
TInd.keys().values
# Out:
# array([('factor', 'Sin ingresos propios'), ('factor', 'UCE'),
#        ('factor', 'UCEP'), ('factor', 'UFR'), ('factor', 'Total')],
#       dtype=object)

# %%
tind=DataFrame()
for i in TInd.keys():
    tind[(i[0],i[1]+' %')]=100*(TInd[i].values/TInd[('factor','Total')].values)

# %%
tind
# Out:
#     (factor, Sin ingresos propios %)  (factor, UCE %)  (factor, UCEP %)  \
# 0                           5.305040         0.000000          0.000000
# 1                           6.129609         9.368937          2.847369
# 2                           9.469572         6.736768          2.353787
# 3                           7.730578        18.604366          4.704382
# 4                           6.378039        27.958269          7.908918
# 5                          12.102042         2.211593          1.152086
# 6                           0.000000         0.000000          0.000000
# 7                          10.034513        13.827275          4.569399
# 8                           8.859254        19.524201          2.487265
# 9                           8.449658        13.046174          5.367289
# 10                          3.739247        14.658645          6.061359
# 11                          7.415343        23.816184          8.476275
# ...

# %%
TInd2=rurales.filter(['Region','CUmun2']).loc[rurales['pertenece a etnia']!=0].pivot_table(index=['Region','CUmun2'],aggfunc=sum,margins=True,margins_name='Total')#.fillna(0)

# %%
#TInd2=DataFrame()
for i in TInd.keys():
    TInd2[(i[1]+' %')]=100*(TInd[i].values/TInd[('factor','Total')].values)

# %%
TInd2=TInd2.rename(index={0:'Localidad mixta',1:'Cercana a ciudad',2:'Cercana a localidad mixta',3:'Cercano a carretera',4:'Aislada'})

# %%
TInd2.round(2)
# Out:
#                                   Sin ingresos propios %  UCE %  UCEP %  \
# Region CUmun2
# Centro Localidad mixta                              5.31   0.00    0.00
#        Cercana a ciudad                             6.13   9.37    2.85
#        Cercana a localidad mixta                    9.47   6.74    2.35
#        Cercano a carretera                          7.73  18.60    4.70
#        Aislada                                      6.38  27.96    7.91
# Norte  Cercana a ciudad                            12.10   2.21    1.15
#        Cercana a localidad mixta                    0.00   0.00    0.00
#        Cercano a carretera                         10.03  13.83    4.57
#        Aislada                                      8.86  19.52    2.49
# Sur    Cercana a ciudad                             8.45  13.05    5.37
#        Cercana a localidad mixta                    3.74  14.66    6.06
#        Cercano a carretera                          7.42  23.82    8.48
# ...

# %%
TInd4=rurales.filter(['factor','Region','CUmun2','tipo_hogar'])

# %%
TInd4=TInd4.pivot_table(index=['Region','CUmun2'],columns='tipo_hogar',aggfunc=sum,margins=True,margins_name='Total')

# %%
TInd4=TInd4.rename(columns={'factor':'Hogares'},index={0:'Localidad mixta',1:'Cercana a ciudad',2:'Cercana a localidad mixta',3:'Cercano a carretera',4:'Aislada'}).fillna(0)

# %%
TInd=TInd.rename(columns={'factor':'Hogares'})

# %%
TInd4[('Hogares Rurales','Total Indigenas')]=TInd[('factor','Total')].astype('int')

# %%
TInd4=TInd4.fillna(0).astype('int')

# %%
TInd4[('Hogares Rurales','Total Indigenas')][-1]=TInd4[('Hogares Rurales','Total Indigenas')].sum()

# %%
TInd4
# Out:
#                                               Hogares                       \
# tipo_hogar                       Sin ingresos propios        UCE      UCEP
# Region CUmun2
# Centro Localidad mixta                         2534.0      362.0       0.0
#        Cercana a ciudad                       63748.0    56640.0   15130.0
#        Cercana a localidad mixta              10867.0     7337.0    2635.0
#        Cercano a carretera                    94976.0   146412.0   37890.0
#        Aislada                                45772.0   130498.0   35246.0
# Norte  Cercana a ciudad                       12645.0     3724.0     944.0
#        Cercana a localidad mixta                556.0      139.0       0.0
#        Cercano a carretera                   106735.0   104029.0   28643.0
#        Aislada                                52870.0    73611.0   14240.0
# Sur    Cercana a ciudad                       14134.0    22818.0   10680.0
# ...

# %%
TInd3=TInd

# %%
for i in TInd3.keys().values:
    TInd3[i]=100*TInd[i]/TInd4[i]

# %%
TInd3=TInd3.round(2).fillna(0)

# %%
TInd.to_excel('hogares indigenas por region y CU.xlsx')

# %%
TInd2.round(2).to_excel('hogares indigenas por region y CU_porcentaje relativo.xlsx')
TInd3.to_excel('hogares indigenas por region y CU_porcentaje de hogares rurales.xlsx')

# %%
TInd3=TInd3.rename(columns={'Total':'Indigenas'})

# %%
TInd3['Total']=TInd4['Total']/TInd4['Total']
